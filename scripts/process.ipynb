# %%
import pandas as pd
import numpy as np
import csv,json

# %%
dat = pd.read_csv('data.csv')

# %%
dat = dat[dat['val']==1]

# %%
dat.shape
# Out:
# (960000, 3)

# %%
print(max(dat['x']),min(dat['x']))
# Out:
# 1199 0

# %%
print(max(dat['y']),min(dat['y']))
# Out:
# 865 401

# %%
dat[dat['x']==1]
# Out:
#         val  x    y
# 420001    1  1  850
# 421201    1  1  849
# 422401    1  1  848
# 423601    1  1  847
# 424801    1  1  846
# 426001    1  1  845
# 427201    1  1  844
# 428401    1  1  843
# 429601    1  1  842
# 430801    1  1  841
# 432001    1  1  840
# 433201    1  1  839
# 434401    1  1  838
# 435601    1  1  837
# 436801    1  1  836
# 438001    1  1  835
# 439201    1  1  834
# 440401    1  1  833
# 441601    1  1  832
# 442801    1  1  831
# 444001    1  1  830
# 445201    1  1  829
# 446401    1  1  828
# 447601    1  1  827
# 448801    1  1  826
# 450001    1  1  825
# 451201    1  1  824
# 452401    1  1  823
# 453601    1  1  822
# 454801    1  1  821
# ...     ... ..  ...
# 924001    1  1  430
# 925201    1  1  429
# 926401    1  1  428
# 927601    1  1  427
# 928801    1  1  426
# 930001    1  1  425
# 931201    1  1  424
# 932401    1  1  423
# 933601    1  1  422
# 934801    1  1  421
# 936001    1  1  420
# 937201    1  1  419
# 938401    1  1  418
# ...

# %%
x_vals = dat['x']
len(x_vals)
# Out:
# 244614

# %%
x_vals = list(set(x_vals))
len(x_vals)
# Out:
# 1200

# %%
# np.argmin(kuso[kuso["y"]==1200]["x"])

# %%
# df = pd.DataFrame(index=[], columns=['val','x','y'])
# df

# %%
# rows = dat[dat['x']==x_val].reset_index(drop=True)
# ag = np.argmax(rows['y'])

# %%
df = pd.DataFrame(index=[], columns=['val','x','y'])

# %%
for x_val in x_vals:
    rows = dat[dat['x']==x_val].reset_index(drop=True)
    ma = np.max(rows['y'])
    df = pd.concat([df,rows[rows['y']==ma]])

len(df)
# Out:
# 1200

# %%
df = df.reset_index(drop=False)
len(df)
# Out:
# 1200

# %%
df[df['x']==0]
# Out:
#    index val  x    y
# 0      0   1  0  754

# %%
df['y'] = df['y'] - 400

# %%
df[df['x']==0]
# Out:
#    index val  x    y
# 0      0   1  0  354

# %%
df.to_csv('dat2.csv')

# %%
df.head()
# Out:
#    index val  x    y
# 0      0   1  0  354
# 1      0   1  1  354
# 2      0   1  2  354
# 3      0   1  3  353
# 4      0   1  4  351
